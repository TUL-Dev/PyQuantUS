# %% [markdown]
# # Sample Clarius Analysis

# %%
import os
from pathlib import Path

print(Path().cwd())
os.chdir(Path().cwd().parent)
print(Path().cwd())
# Out:
# c:\0_Main\2_Quantitative_ultrasound\2_github\PyQuantUS\CLI-Demos
# c:\0_Main\2_Quantitative_ultrasound\2_github\PyQuantUS

# %% [markdown]
# # Create raw from tar files

# %%
# from pyquantus.parse.clarius import ClariusTarUnpacker

# path = '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/PDG1738089148213.tar'
# extraction_mode = "single_tar"  # "single_sample", "multiple_samples", "single_tar"

# ClariusTarUnpacker(path, extraction_mode)

# %%
from pyquantus.parse.clarius import ClariusTarUnpacker

path = r'D:\Omid\0_samples\6_test_with_without_gain\10.02.2025'
extraction_mode = "single_sample"  # "single_sample", "multiple_samples", "single_tar"

ClariusTarUnpacker(path, extraction_mode)
# Out:
# 2025-03-19 09:36:47,614 - INFO - Deleted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted
# 2025-03-19 09:36:47,616 - INFO - Deleted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_1_extracted
# 2025-03-19 09:36:47,623 - INFO - Deleted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_2_extracted
# 2025-03-19 09:36:47,626 - INFO - Deleted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_3_extracted
# 2025-03-19 09:36:48,026 - INFO - Extracted 'raw_0.tar' into 'D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted'
# 2025-03-19 09:36:48,145 - INFO - Extracted 'raw_1.tar' into 'D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_1_extracted'
# 2025-03-19 09:36:48,576 - INFO - Extracted 'raw_2.tar' into 'D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_2_extracted'
# 2025-03-19 09:36:48,793 - INFO - Extracted 'raw_3.tar' into 'D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_3_extracted'
# 2025-03-19 09:36:48,793 - INFO - Searching for extracted folders...
# 2025-03-19 09:36:48,793 - INFO - Found extracted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted
# 2025-03-19 09:36:48,796 - INFO - Found extracted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_1_extracted
# 2025-03-19 09:36:48,796 - INFO - Found extracted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_2_extracted
# 2025-03-19 09:36:48,797 - INFO - Found extracted folder: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_3_extracted
# 2025-03-19 09:36:48,797 - INFO - Total extracted folders found: 4
# 2025-03-19 09:36:48,797 - INFO - Starting to search for LZO files inside extracted folders...
# 2025-03-19 09:36:48,797 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_rf.raw.lzo
# 2025-03-19 09:36:48,802 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_env.raw.lzo
# 2025-03-19 09:36:48,803 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_1_extracted\2025-01-28T07-21-26+0000_rf.raw.lzo
# 2025-03-19 09:36:48,805 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_1_extracted\2025-01-28T07-21-26+0000_env.raw.lzo
# 2025-03-19 09:36:48,807 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_2_extracted\2025-01-28T07-25-46+0000_rf.raw.lzo
# 2025-03-19 09:36:48,809 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_2_extracted\2025-01-28T07-25-46+0000_env.raw.lzo
# 2025-03-19 09:36:48,810 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_3_extracted\2025-01-28T07-26-24+0000_rf.raw.lzo
# 2025-03-19 09:36:48,810 - INFO - Found LZO file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw
D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_2_extracted\2025-01-28t07-25-46+0000_env.raw
# 2025-03-19 09:36:49,673 - INFO - Found RAW file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_3_extracted\2025-01-28t07-26-24+0000_rf.raw
# 2025-03-19 09:36:49,673 - INFO - Found RAW file: D:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_3_extracted\2025-01-28t07-26-24+0000_env.raw
# 2025-03-19 09:36:49,673 - INFO - Total RAW files found: 8
# ClariusTarUnpacker

# %%
from pyquantus.parse.clarius import ClariusParser

path = r'd:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted'

obj = ClariusParser(path, visualize=True)
# Out:
# 2025-03-19 09:36:49,687 - INFO - All required files are present.
# 2025-03-19 09:36:49,687 - INFO - Scanning directory: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted
# 2025-03-19 09:36:49,689 - INFO - Found _rf.yml: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_rf.yml
# 2025-03-19 09:36:49,690 - INFO - Found _env.yml: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_env.yml
# 2025-03-19 09:36:49,690 - INFO - Found _env.tgc.yml: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_env.tgc.yml
# 2025-03-19 09:36:49,690 - INFO - YAML file path setting completed.
# 2025-03-19 09:36:49,692 - INFO - File format detected after last underscore: rf.yml
# 2025-03-19 09:36:49,766 - INFO - Version 12.0.1-673 is valid.
# 2025-03-19 09:36:49,767 - INFO - File format detected after last underscore: env.yml
# 2025-03-19 09:36:49,830 - INFO - Version 12.0.1-673 is valid.
# 2025-03-19 09:36:49,831 - INFO - File format detected after last underscore: env.tgc.yml
# 2025-03-19 09:36:49,841 - INFO - Scanning directory: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted for RAW files
# 2025-03-19 09:36:49,842 - INFO - Found _rf.raw: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28t07-20-59+0000_rf.raw
# 2025-03-19 09:36:49,843 - INFO - Found _env.raw: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28t07-20-59+0000_env.raw
# 2025-03-19 09:36:49,843 - INFO - RAW file path setting completed.
# 2025-03-19 09:36:49,844 - INFO - Reading raw RF file: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28t07-20-59+0000_rf.raw
# 2025-03-19 09:36:49,844 - INFO - Opened file successfully.
# 2025-03-19 09:36:49,845 - INFO - Parsed header: {'id': 2, 'frames': 34, 'lines': 192, 'samples': 2928, 'samplesize': 2}
# 2025-03-19 09:36:50,067 - INFO - Successfully read 34 RF frames.
# 2025-03-19 09:36:50,072 - INFO - Loaded 34 raw RF frames of size 192 x 2928 (lines x samples)
# 2025-03-19 09:36:50,072 - INFO - Reading raw environmental data from: d:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28t07-20-59+0000_env.raw
# 2025-03-19 09:36:50,073 - INFO - Opened file successfully.
# 2025-03-19 09:36:50,074 - INFO - Parsed header: {'id': 1, 'frames': 34, 'lines': 192, 'samples': 656, 'samplesize': 1}
# 2025-03-19 09:36:50,084 - INFO - Successfully read 34 frames.
# 2025-03-19 09:36:50,084 - INFO - Loaded 34 raw frames of size 192 x 656 (lines x samples)
# 2025-03-19 09:36:50,085 - INFO - Final data stored for 61804357200: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.17}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 35.62}, {'depth': 112.5, 'dB': 35.98}, {'depth': 127.5, 'dB': 36.74}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,085 - INFO - Final data stored for 61895766460: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.17}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 35.62}, {'depth': 112.5, 'dB': 35.98}, {'depth': 127.5, 'dB': 36.74}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50
, {'depth': 127.5, 'dB': 36.74}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,098 - INFO - Final data stored for 63905896540: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 36.74}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,099 - INFO - Final data stored for 63997283860: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.17}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,099 - INFO - Final data stored for 64088801910: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.17}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,100 - INFO - Final data stored for 64180264290: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.17}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,100 - INFO - Final data stored for 64271562700: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.44}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,100 - INFO - Final data stored for 64363088890: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.44}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,103 - INFO - Final data stored for 64454370430: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.44}, {'depth': 142.5, 'dB': 39.07}]
# 2025-03-19 09:36:50,105 - INFO - Final data stored for 64545752480: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.78}, {'depth': 142.5, 'dB': 39.44}]
# 2025-03-19 09:36:50,105 - INFO - Final data stored for 64637288100: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.78}, {'depth': 142.5, 'dB': 39.44}]
# 2025-03-19 09:36:50,106 - INFO - Final data stored for 64728581370: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.78}, {'depth': 142.5, 'dB': 39.44}]
# 2025-03-19 09:36:50,106 - WARNING - No valid data for 64819833600, using previous valid data.
# 2025-03-19 09:36:50,106 - INFO - Final data stored for 64819833600: [{'depth': 7.5, 'dB': 5.0}, {'depth': 22.5, 'dB': 13.04}, {'depth': 37.5, 'dB': 24.62}, {'depth': 52.5, 'dB': 27.55}, {'depth': 67.5, 'dB': 31.58}, {'depth': 82.5, 'dB': 35.23}, {'depth': 97.5, 'dB': 36.6}, {'depth': 112.5, 'dB': 36.6}, {'depth': 127.5, 'dB': 37.78}, {'depth': 142.5, 'dB': 39.44}]
# 100%|██████████| 34/34 [01:01<00:00,  1.82s/it]
# 2025-03-19 09:38:18,507 - INFO - Starting the plot function.
# 2025-03-19 09:38:18,747 - INFO - Displayed 2D Signal Envelope.
# 2025-03-19 09:38:19,366 - INFO - Plotting completed and displayed.
# 2025-03-19 09:38:19,380 - INFO - Starting the plot function.
# 2025-03-19 09:38:19,411 - INFO - Displayed 2D Signal Envelope.
# 2025-03-19 09:38:19,753 - INFO - Plotting completed and displayed.

# %%
# from pyquantus.parse.clarius import clariusRfParser

# rf_path = r'd:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28t07-20-59+0000_rf.raw'
# rf_tgc_path = r'd:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_env.tgc.yml'
# info_path = r'd:\Omid\0_samples\6_test_with_without_gain\10.02.2025\raw_0_extracted\2025-01-28T07-20-59+0000_rf.yml'

# imgData, imgInfo, refData, refInfo, scanConverted = clariusRfParser(rf_path, rf_tgc_path, info_path,
#                                                                     rf_path, rf_tgc_path, info_path) # image = phantom for now

# %% [markdown]
# # Select Image & Phantom and Parse

# %%
from pyquantus.parse.clarius import clariusRfParser

rf_path = '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/PDG1738089148213_extracted/2025-01-28T18-45-21+0000_rf.raw'
rf_tgc_path = '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/PDG1738089148213_extracted/2025-01-28T18-45-21+0000_env.tgc.yml'
info_path = '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/PDG1738089148213_extracted/2025-01-28T18-45-21+0000_rf.yml'

imgData, imgInfo, refData, refInfo, scanConverted = clariusRfParser(rf_path, rf_tgc_path, info_path,
                                                       rf_path, rf_tgc_path, info_path) # image = phantom for now
# Out:
# 2025-03-19 09:38:20,325 - ERROR - The path 'c:\Users\davidspector\Home\Stanford\QuantUS Projects\Sample Data\Clarius RF\PDG1738089148213_extracted' is NOT a valid folder.
# 2025-03-19 09:38:20,326 - ERROR - The path 'c:\Users\davidspector\Home\Stanford\QuantUS Projects\Sample Data\Clarius RF\PDG1738089148213_extracted' is NOT a valid folder.

# %% [markdown]
# # ROI Selection (from GUI)

# %%
import pickle

pkl_name = '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/a896ef50-1922-4df2-8995-a57b5a46d800/roi.pkl'

with open(pkl_name, 'rb') as f:
    roi_info = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 import pickle
#       3 pkl_name = '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/a896ef50-1922-4df2-8995-a57b5a46d800/roi.pkl'
# ----> 5 with open(pkl_name, 'rb') as f:
#       6     roi_info = pickle.load(f)
#
# File c:\Users\ochag\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/davidspector/Home/Stanford/QuantUS Projects/Sample Data/Clarius RF/a896ef50-1922-4df2-8995-a57b5a46d800/roi.pkl'

# %%
from pathlib import Path

assert roi_info['Image Name'] == Path(rf_path).name
assert roi_info['Phantom Name'] == Path(rf_path).name

# %%
scSplineX = roi_info["Spline X"]
scSplineY = roi_info["Spline Y"]
frame = roi_info["Frame"]

# %% [markdown]
# # Analysis Config (from GUI)

# %%
from pyquantus.utc import AnalysisConfig

config = AnalysisConfig()

config.transducerFreqBand = [0, 8000000] # [min, max] (Hz)
config.analysisFreqBand = [2000000, 6000000] # [lower, upper] (Hz)
config.samplingFrequency = 15000000 # Hz
config.axWinSize = 3.85 # axial length per window (mm)
config.latWinSize = 3.85 # lateral length per window (mm)
config.windowThresh = 0.95 # % of window area required to be considered in ROI
config.axialOverlap = 0.5 # % of window overlap in axial direction
config.lateralOverlap = 0.5 # % of window overlap in lateral direction
config.centerFrequency = 3000000 # Hz

# %% [markdown]
# # UTC Analysis

# %%
from pyquantus.utc import UltrasoundImage

frame = 0

ultrasoundImage = UltrasoundImage()
ultrasoundImage.axialResRf = imgInfo.depth / imgData.rf[frame].shape[0]
ultrasoundImage.lateralResRf = ultrasoundImage.axialResRf * (
    imgData.rf[frame].shape[0]/imgData.rf[frame].shape[1]
) # placeholder
ultrasoundImage.bmode = imgData.bMode[frame]
ultrasoundImage.scBmode = imgData.scBmode[frame]
ultrasoundImage.phantomRf = refData.rf[0]
ultrasoundImage.rf = imgData.rf[frame]
ultrasoundImage.xmap = imgData.scBmodeStruct.xmap
ultrasoundImage.ymap = imgData.scBmodeStruct.ymap

# %%
from pyquantus.utc import UtcAnalysis

utcAnalysis = UtcAnalysis()
utcAnalysis.ultrasoundImage = ultrasoundImage
utcAnalysis.config = config
utcAnalysis.initAnalysisConfig()
utcAnalysis.scSplineX = scSplineX
utcAnalysis.scSplineY = scSplineY

# %%
utcAnalysis.refAttenuation = 0.5 # placeholder for attenuation coefficient at center freq (dB/cm/MHz)
utcAnalysis.refBackScatterCoef = 10e-3 # placeholder for backscatter coefficient at center freq (cm^-1 sr^-1)

# %%
utcAnalysis.splineToPreSc()
utcAnalysis.generateRoiWindows()
utcAnalysis.computeUtcWindows();

# %%
import numpy as np

mbfArr = [window.results.mbf for window in utcAnalysis.roiWindows]
ssArr = [window.results.ss for window in utcAnalysis.roiWindows]
siArr = [window.results.si for window in utcAnalysis.roiWindows]

print("Average Midband Fit:", np.mean(mbfArr), "dB")
print("Average Spectral Slope:", np.mean(ssArr), "dB/MHz")
print("Average Spectral Intercept:", np.mean(siArr), "dB")
print("Attenuation Coefficient:", utcAnalysis.attenuationCoef, "dB/cm/MHz")
print("Backscatter Coefficient:", utcAnalysis.backScatterCoef, "1/cm-sr")
print("w Nakagami Parameter:", utcAnalysis.nakagamiParams[0])
print("u Nakagami Parameter:", utcAnalysis.nakagamiParams[1])
print("Effective Scatterer Diameter:", utcAnalysis.effectiveScattererDiameter, "µm") 
print("Effective Scatterer Concentration:", utcAnalysis.effectiveScattererConcentration, "dB/mm^3")
# Out:
# Average Midband Fit: 0.0 dB
# Average Spectral Slope: 0.0 dB/MHz
# Average Spectral Intercept: 0.0 dB
# Attenuation Coefficient: 0.5 dB/cm/MHz
# Backscatter Coefficient: 0.01 1/cm-sr
# w Nakagami Parameter: 50196.39130843499
# u Nakagami Parameter: 1.1925533517873792
# Effective Scatterer Diameter: 0.17673598070839378 µm
# Effective Scatterer Concentration: 167.10417712573096 dB/mm^3

# %% [markdown]
# # Visualizations

# %%
from pyquantus.utc import UtcData
from pyquantus.parse.objects import ScConfig

scConfig = ScConfig()
scConfig.width = imgInfo.width1
scConfig.tilt = imgInfo.tilt1
scConfig.startDepth = imgInfo.startDepth1
scConfig.endDepth = imgInfo.endDepth1

utcData = UtcData()
utcData.utcAnalysis = utcAnalysis
utcData.scConfig = scConfig

# %%
utcData.convertImagesToRGB()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow(utcData.scBmode, aspect='auto')
plt.plot(scSplineX, scSplineY);

# %%
utcData.drawCmaps()
utcData.scanConvertCmaps()

# %%
# Note cmap is solid as image = phantom in this case
plt.imshow(utcData.scMbfIm)
plt.plot(scSplineX, scSplineY);
